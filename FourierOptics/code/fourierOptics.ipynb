# %%
# Jupyter notebook for our fourier Optics experiment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import skimage

# %%
# Use this notebook to do image reduction/other imaging analysis

xx = np.arange(0,3,0.1)# input data
yy = 
ft = np.fft.fft(yy)

# %%
print('input: ', xx)
print('output: ', yy)
print('Fourier Transform: ', ft)
# Out:
# input:  [0.9317585  0.62987161 0.04441616 0.4932514  0.12583522 0.65866627
#  0.91183482 0.42611289 0.57968442 0.50413603]
# output:  [13.90043679  8.56348921  1.44822666  6.62785034  2.2928539   9.00277938
#  13.48922705  5.75376334  7.82539592  6.77394918]
# Fourier Transform:  [75.67797177+0.00000000e+00j  3.57751195+1.07629400e+01j
#  15.00022234-8.08815586e+00j  7.54947713+5.71179933e+00j
#   4.41883219-1.45292828e+01j  2.23430886-8.88178420e-16j
#   4.41883219+1.45292828e+01j  7.54947713-5.71179933e+00j
#  15.00022234+8.08815586e+00j  3.57751195-1.07629400e+01j]

# %%
# plotting idk
f,ax = plt.subplots()
ax.plot(xx, yy, c = 'r')
ax.plot(xx, ft, c = 'g')
